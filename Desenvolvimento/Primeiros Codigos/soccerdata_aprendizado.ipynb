# %%
# Importando as Bibliotecas
import soccerdata as sd
import pandas as pd
from pathlib import Path

from soccerdata import ClubElo # As forças relativas da equipe em classificações Elo, na maioria das ligas europeias. Recalculado após cada rodada, inclui histórico.
from soccerdata import ESPN # Resultados históricos, estatísticas e escalações.
from soccerdata import FBref # Resultados históricos, escalações e estatísticas agregadas detalhadas para times e jogadores individuais com base em dados da Opta.
from soccerdata import MatchHistory # Resultados históricos, odds de apostas e estatísticas de partidas. O nível de detalhe depende da liga.
from soccerdata import Sofascore # Resultados, calendários, escalações e estatísticas detalhadas para times e jogadores individuais.
from soccerdata import SoFIFA # Pontuações detalhadas sobre todas as habilidades dos jogadores do EA Sports FC.
from soccerdata import Understat # Estatísticas avançadas como xG, xGBuildup e xGChain, e eventos de arremesso com valores xG associados para as principais ligas europeias.
from soccerdata import WhoScored # Resultados históricos, dados de prévia de partidas e dados detalhados de transmissões de eventos Opta para as grandes ligas.

# %% [markdown]
# # Extração de Dados

# %%
# Criar instância da classe scraper
fbref = sd.FBref()
# Out:
# [05/29/26 16:58:04] INFO     Saving cached data to C:\Users\raphael.eugenio\soccerdata\data\FBref    ]8;id=182835;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=503013;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#250\250]8;;\
# [05/29/26 16:58:06] INFO     No seasons provided. Will retrieve data for the last 5 seasons.         ]8;id=82785;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=575280;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#462\462]8;;\

# %%
# Criar Dataframes
season_stats = fbref.read_team_season_stats(stat_type="shooting")
# Out:
#                     WARNING  c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\L ]8;id=555542;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\_py_warnings.py\_py_warnings.py]8;;\:]8;id=636161;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\_py_warnings.py#230\230]8;;\
#                              ib\site-packages\soccerdata\_common.py:144: UserWarning: Season id
#                              "2021" is ambiguous: interpreting as "20-21"
#                                warnings.warn(msg, stacklevel=1)

# %%
# Criar instância da classe scraper filtrando por ligas e temporadas específicas
fbref = sd.FBref(leagues=["Big 5 European Leagues Combined"], seasons=["2017", "2024"])

# Recuperar dados para as ligas e temporada especificadas
season_stats = fbref.read_team_season_stats(stat_type="shooting")
# Out:
# [05/29/26 16:58:09] INFO     Saving cached data to C:\Users\raphael.eugenio\soccerdata\data\FBref    ]8;id=76932;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=791589;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#250\250]8;;\

# %%
sd.FBref.available_leagues()
# Out:
# ['Big 5 European Leagues Combined',
#  'INT-European Championship',
#  "INT-Women's World Cup",
#  'INT-World Cup']

# %%
# Printa as ligas disponiveis
print(sorted(fbref.available_leagues()))
# Out:
# ['Big 5 European Leagues Combined', 'INT-European Championship', "INT-Women's World Cup", 'INT-World Cup']

# %% [markdown]
# # Configuração Global

# %%
# Definindo caminho
fbref = sd.FBref(
    data_dir=Path(r"C:/Users/raphael.eugenio/Desktop/Raphael/Soccerdata")
)
# Out:
# [05/29/26 16:58:18] INFO     Saving cached data to                                                   ]8;id=396547;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=482016;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#250\250]8;;\
#                              C:\Users\raphael.eugenio\Desktop\Raphael\Soccerdata
# [05/29/26 16:58:26] INFO     No seasons provided. Will retrieve data for the last 5 seasons.         ]8;id=332960;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=128663;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#462\462]8;;\

# %%
fbref = sd.FBref(
    leagues=["Big 5 European Leagues Combined"],
    seasons=[2024],
    data_dir=Path(r"C:\Users\raphael.eugenio\soccerdata")
)
# Out:
# [05/29/26 16:58:27] INFO     Saving cached data to C:\Users\raphael.eugenio\soccerdata               ]8;id=689440;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=918440;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#250\250]8;;\

# %% [markdown]
# # ClubElo

# %%
# Dados do ClubElo, mede por Ranking historico
elo = sd.ClubElo()
print(elo.__doc__)
# Out:
# [05/29/26 16:58:38] INFO     Saving cached data to C:\Users\raphael.eugenio\soccerdata\data\ClubElo  ]8;id=571983;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=353599;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#250\250]8;;\
# [2026-05-29 16:58:38] INFO     TLSLibrary:_load_library:397 - Successfully loaded TLS library: C:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\tls_requests\bin\tls-client-xgo-1.13.1-windows-amd64.dll
# ...

# %%
current_elo = elo.read_by_date()
current_elo.head()
# Out:
#            rank country  level          elo       from         to  \
# team
# Arsenal     1.0     ENG      1  2065.758057 2026-05-25 2026-05-30
# Bayern      2.0     GER      1  2000.870239 2026-05-21 2026-05-31
# Man City    3.0     ENG      1  1969.962524 2026-05-25 2026-05-31
# Paris SG    4.0     FRA      1  1964.038452 2026-05-24 2026-05-30
# Barcelona   5.0     ESP      1  1953.367310 2026-05-24 2026-05-31
#
#                        league
# team
# Arsenal    ENG-Premier League
# Bayern         GER-Bundesliga
# Man City   ENG-Premier League
# Paris SG          FRA-Ligue 1
# Barcelona         ESP-La Liga

# %%
barca_elo = elo.read_team_history("Barcelona")
barca_elo.head()
# Out:
#             rank       team country  level          elo         to
# from
# 1939-10-22   NaN  Barcelona     ESP      1  1636.704590 1939-12-03
# 1939-12-04   NaN  Barcelona     ESP      1  1626.102173 1939-12-10
# 1939-12-11   NaN  Barcelona     ESP      1  1636.728271 1939-12-17
# 1939-12-18   NaN  Barcelona     ESP      1  1646.951660 1939-12-24
# 1939-12-25   NaN  Barcelona     ESP      1  1637.424316 1939-12-31

# %%
real_elo = elo.read_team_history("Real Madrid")
real_elo.head()
# Out:
#             rank         team country  level          elo         to
# from
# 1939-10-22   NaN  Real Madrid     ESP      1  1636.704590 1939-12-03
# 1939-12-04   NaN  Real Madrid     ESP      1  1621.710571 1939-12-10
# 1939-12-11   NaN  Real Madrid     ESP      1  1616.419678 1939-12-17
# 1939-12-18   NaN  Real Madrid     ESP      1  1625.154663 1939-12-24
# 1939-12-25   NaN  Real Madrid     ESP      1  1635.314575 1939-12-31

# %% [markdown]
# # ESPN

# %%
# Definindo Liga e Temporada
espn = sd.ESPN(leagues = "ENG-Premier League", seasons=2021)
print(espn.__doc__)
# Out:
# [05/29/26 16:58:39] INFO     Saving cached data to C:\Users\raphael.eugenio\soccerdata\data\ESPN     ]8;id=802171;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=590716;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#250\250]8;;\
#                     WARNING  c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\L ]8;id=875700;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\_py_warnings.py\_py_warnings.py]8;;\:]8;id=314487;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\_py_warnings.py#230\230]8;;\
#                              ib\site-packages\soccerdata\_common.py:144: UserWarning: Season id
#                              "2021" is ambiguous: interpreting as "20-21"
#                                warnings.warn(msg, stacklevel=1)
# ...

# %% [markdown]
# *Calendário de Jogos*

# %%
# Calendário da temporada inteira
epl_schedule = espn.read_schedule()
epl_schedule
# Out:
#                                                                                            date  \
# league             season game
# ENG-Premier League 2021   2019-08-09 Liverpool-Norwich City           2019-08-09 19:00:00+00:00
#                           2019-08-10 AFC Bournemouth-Sheffield United 2019-08-10 14:00:00+00:00
#                           2019-08-10 Burnley-Southampton              2019-08-10 14:00:00+00:00
#                           2019-08-10 Crystal Palace-Everton           2019-08-10 14:00:00+00:00
#                           2019-08-10 Tottenham Hotspur-Aston Villa    2019-08-10 16:30:00+00:00
# ...                                                                                         ...
#                           2020-07-26 Leicester City-Manchester United 2020-07-26 15:00:00+00:00
#                           2020-07-26 Manchester City-Norwich City     2020-07-26 15:00:00+00:00
# ...

# %% [markdown]
# *Estatísticas do jogo*

# %%
# Estatisticas dos jogos por partida selecionando por id
matchsheet = espn.read_matchsheet(match_id=541470)
matchsheet.head()
# Out:
#                                                                                    is_home  \
# league             season game                                    team
# ENG-Premier League 2021   2020-07-26 Manchester City-Norwich City Manchester City     True
#                                                                   Norwich City       False
#
#                                                                                             venue  \
# league             season game                                    team
# ENG-Premier League 2021   2020-07-26 Manchester City-Norwich City Manchester City  Etihad Stadium
#                                                                   Norwich City     Etihad Stadium
#
#                                                                                    attendance  \
# league             season game                                    team
# ...

# %% [markdown]
# *Formações de Jogo*

# %%
# Formação de Jogo por ID
lineups = espn.read_lineup(match_id=541470)
lineups
# Out:
#                                                                                                        is_home  \
# league             season game                                    team            player
# ENG-Premier League 2021   2020-07-26 Manchester City-Norwich City Manchester City Aymeric Laporte         True
#                                                                                   Benjamin Mendy          True
#                                                                                   Bernardo Silva          True
#                                                                                   David Silva             True
#                                                                                   Ederson                 True
#                                                                                   Eric García             True
#                                                                                   Fernandinho             True
# ...

# %% [markdown]
# # FBref

# %%
fbref = sd.FBref(leagues = "INT-World Cup", seasons = 2018)
print(fbref.__doc__)
# Out:
# [05/29/26 16:58:43] INFO     Saving cached data to C:\Users\raphael.eugenio\soccerdata\data\FBref    ]8;id=973553;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=937156;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#250\250]8;;\
# Provides pd.DataFrames from data at http://fbref.com.
#
# Data will be downloaded as necessary and cached locally in
# ``~/soccerdata/data/FBref``.
#
# Parameters
# ----------
# leagues : string or iterable, optional
#     IDs of leagues to include. For efficiently reading data from the Top-5
#     European leagues, use "Big 5 European Leagues Combined".
# seasons : string, int or list, optional
#     Seasons to include. Supports multiple formats.
#     Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
# proxy : 'tor' or or dict or list(dict) or callable, optional
# ...

# %% [markdown]
# *Estatísticas da Temporada da equipe*

# %%
team_season_stats = fbref.read_team_season_stats(stat_type = "shooting")
team_season_stats
# Out:
#                                     players_used  90s Standard                 \
#                                                            Gls   Sh SoT  SoT%
# league        season team
# INT-World Cup 2018   Argentina                20  4.0        6   58  17  29.3
#                      Australia                15  3.0        2   29   5  17.2
#                      Belgium                  21  7.0       15  104  37  35.6
#                      Brazil                   18  5.0        8  106  38  35.8
#                      Colombia                 20  4.3        6   40  12  30.0
#                      Costa Rica               20  3.0        1   26   9  34.6
#                      Croatia                  21  8.0       13  114  27  23.7
#                      Denmark                  20  4.3        3   40  12  30.0
#                      Egypt                    16  3.0        2   29   4  13.8
#                      England                  21  7.7       12   88  22  25.0
# ...

# %% [markdown]
# *Estatísticas da partida por equipes*

# %%
team_match_stats = fbref.read_team_match_stats(stat_type = "schedule", team = "Brazil")
team_match_stats
# Out:
#                                                               date      time  \
# league season team   game
# <NA>   2018   Brazil 2015-10-08 Chile-Brazil            2015-10-08  20:30:00
#                      2015-10-13 Brazil-Venezuela        2015-10-13  22:00:00
#                      2015-11-13 Argentina-Brazil        2015-11-13  21:00:00
#                      2015-11-17 Brazil-Peru             2015-11-17  21:00:00
#                      2016-03-25 Brazil-Uruguay          2016-03-25  21:45:00
#                      2016-03-29 Paraguay-Brazil         2016-03-29  20:45:00
#                      2016-09-01 Ecuador-Brazil          2016-09-01  16:00:00
#                      2016-09-06 Brazil-Colombia         2016-09-06  20:45:00
#                      2016-10-06 Brazil-Bolivia          2016-10-06  21:45:00
#                      2016-10-11 Venezuela-Brazil        2016-10-11  20:30:00
#                      2016-11-10 Brazil-Argentina        2016-11-10  21:45:00
# ...

# %% [markdown]
# *Estatísticas da temporada dos jogadores*

# %%
player_season_stats = fbref.read_player_season_stats(stat_type = 'standard')
player_season_stats
# Out:
#                                                      nation    pos age  born  \
#
# league        season team      player
# INT-World Cup 2018   Argentina Cristian Pavón     Argentina     FW  22  1996
#                                Eduardo Salvio     Argentina  MF,DF  27  1990
#                                Enzo Pérez         Argentina     MF  32  1986
#                                Federico Fazio     Argentina     DF  31  1987
#                                Franco Armani      Argentina     GK  31  1986
# ...                                                     ...    ...  ..   ...
#                      Uruguay   Matías Vecino        Uruguay     MF  26  1991
#                                Maxi Gómez           Uruguay     FW  21  1996
#                                Nahitan Nández       Uruguay     MF  22  1995
#                                Rodrigo Bentancur    Uruguay  MF,FW  20  1997
#                                Sebastián Coates     Uruguay     DF  27  1990
#
# ...

# %% [markdown]
# *Calendário de Jogos*

# %%
world_games = fbref.read_schedule()
world_games
# Out:
#                                                                  round  week  \
# league        season game
# INT-World Cup 2018   2018-06-14 Russia-Saudi Arabia        Group stage     1
#                      2018-06-15 Egypt-Uruguay              Group stage     1
#                      2018-06-15 Morocco-IR Iran            Group stage     1
#                      2018-06-15 Portugal-Spain             Group stage     1
#                      2018-06-16 Argentina-Iceland          Group stage     1
# ...                                                                ...   ...
#                      2018-07-07 Sweden-England          Quarter-finals  <NA>
#                      2018-07-10 France-Belgium             Semi-finals  <NA>
#                      2018-07-11 Croatia-England            Semi-finals  <NA>
#                      2018-07-14 Belgium-England      Third-place match  <NA>
#                      2018-07-15 France-Croatia                   Final  <NA>
#
# ...

# %% [markdown]
# *Estatísticas das partidas dos jogadores*

# %%
player_match_stats = fbref.read_player_match_stats(stat_type = "summary", match_id = "a7957cf1")
player_match_stats
# Out:
# [05/29/26 16:59:13] INFO     [1/1] Retrieving game with id=a7957cf1                                    ]8;id=750550;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\fbref.py\fbref.py]8;;\:]8;id=600102;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\fbref.py#765\765]8;;\
#                     WARNING  c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\L ]8;id=2994;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\_py_warnings.py\_py_warnings.py]8;;\:]8;id=735273;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\_py_warnings.py#230\230]8;;\
#                              ib\site-packages\soccerdata\fbref.py:776: FutureWarning: This
#                              search incorrectly ignores the root element, and will be fixed in
# ...

# %% [markdown]
# *Formações*

# %%
lineups = fbref.read_lineup(match_id = "a7957cf1")
lineups
# Out:
#                     INFO     [1/1] Retrieving game with id=a7957cf1                                    ]8;id=480735;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\fbref.py\fbref.py]8;;\:]8;id=727703;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\fbref.py#854\854]8;;\
#                     WARNING  c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\L ]8;id=239405;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\_py_warnings.py\_py_warnings.py]8;;\:]8;id=77900;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\_py_warnings.py#230\230]8;;\
#                              ib\site-packages\soccerdata\fbref.py:880: FutureWarning: This
#                              search incorrectly ignores the root element, and will be fixed in
# ...

# %% [markdown]
# *Eventos*

# %%
events = fbref.read_events(match_id='a7957cf1')
events
# Out:
# [05/29/26 16:59:52] INFO     [1/1] Retrieving game with id=a7957cf1                                    ]8;id=830677;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\fbref.py\fbref.py]8;;\:]8;id=47035;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\fbref.py#949\949]8;;\
#                                                    team minute score  \
# league        season game
# INT-World Cup 2018   2018-07-15 France-Croatia   France    18’   1:0
#                      2018-07-15 France-Croatia   France    27’   1:0
#                      2018-07-15 France-Croatia  Croatia    28’   1:1
#                      2018-07-15 France-Croatia   France    38’   2:1
#                      2018-07-15 France-Croatia   France    41’   2:1
#                      2018-07-15 France-Croatia   France    54’   2:1
#                      2018-07-15 France-Croatia   France    59’   3:1
# ...

# %% [markdown]
# # Históricos de Partidas

# %%
mh = sd.MatchHistory(leagues= "GER-Bundesliga", seasons = 2022)
print(mh.__doc__)
# Out:
# [05/29/26 17:19:26] INFO     Saving cached data to                                                   ]8;id=984770;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=126273;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#250\250]8;;\
#                              C:\Users\raphael.eugenio\soccerdata\data\MatchHistory
# Provides pd.DataFrames from CSV files available at http://www.football-data.co.uk/data.php.
#
# Data will be downloaded as necessary and cached locally in
# ``~/soccerdata/data/MatchHistory``.
#
# Parameters
# ----------
# leagues : string or iterable
#     IDs of leagues to include.
# seasons : string, int or list
#     Seasons to include. Supports multiple formats.
#     Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
# proxy : 'tor' or or dict or list(dict) or callable, optional
# ...

# %%
hist = mh.read_games()
hist.head()
# Out:
# [05/29/26 17:19:36] ERROR    Error while scraping                                                    ]8;id=80000;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=588011;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#527\527]8;;\
#                              https://www.football-data.co.uk/mmz4281/2223/D1.csv. Retrying...
#                              (attempt 1 of 5).
#                              Traceback (most recent call last):
#                                File
#                              "c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\s
#                              ite-packages\soccerdata\_common.py", line 507, in _download_and_save
#                                  response.raise_for_status()
#                                  ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#                                File
# ...

# %% [markdown]
# # Sofascore

# %%
sofascore = sd.Sofascore(leagues="ESP-La Liga", seasons="2022/2023")
print(sofascore.__doc__)
# Out:
# [05/29/26 17:36:42] INFO     Saving cached data to                                                   ]8;id=895681;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=298562;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#250\250]8;;\
#                              C:\Users\raphael.eugenio\soccerdata\data\Sofascore
# Provides pd.DataFrames from data available at http://www.sofascore.com.
#
# Data will be downloaded as necessary and cached locally in
# ``~/soccerdata/data/Sofascore``.
#
# Parameters
# ----------
# leagues : string or iterable, optional
#     IDs of Leagues to include.
# seasons : string, int or list, optional
#     Seasons to include. Supports multiple formats.
#     Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
# proxy : 'tor' or or dict or list(dict) or callable, optional
# ...

# %% [markdown]
# *Tabela de Classificação*

# %%
league_table = sofascore.read_league_table()
league_table.head()
# Out:
#                                team  MP   W  D   L  GF  GA  GD  Pts
# league      season
# ESP-La Liga 2223       FC Barcelona  38  28  4   6  70  20  50   88
#             2223        Real Madrid  38  24  6   8  75  36  39   78
#             2223    Atlético Madrid  38  23  8   7  70  33  37   77
#             2223      Real Sociedad  38  21  8   9  51  35  16   71
#             2223         Villarreal  38  19  7  12  59  40  19   64

# %% [markdown]
# *Jogos (Crornogramas)*

# %%
schedule = sofascore.read_schedule()
schedule.head()
# Out:
#                                                            round  week  \
# league      season game
# ESP-La Liga 2223   2022-08-12 Osasuna-Sevilla                  1     1
#                    2022-08-13 Celta Vigo-Espanyol              1     1
#                    2022-08-13 FC Barcelona-Rayo Vallecano      1     1
#                    2022-08-13 Real Valladolid-Villarreal       1     1
#                    2022-08-14 Almería-Real Madrid              1     1
#
#                                                                                date  \
# league      season game
# ESP-La Liga 2223   2022-08-12 Osasuna-Sevilla             2022-08-12 19:00:00+00:00
#                    2022-08-13 Celta Vigo-Espanyol         2022-08-13 15:00:00+00:00
#                    2022-08-13 FC Barcelona-Rayo Vallecano 2022-08-13 19:00:00+00:00
#                    2022-08-13 Real Valladolid-Villarreal  2022-08-13 17:00:00+00:00
# ...

# %% [markdown]
# # Understat

# %%
understat = sd.Understat(leagues = "GER-Bundesliga", seasons = "2024/2025")
print(understat.__doc__)
# Out:
# [05/29/26 17:39:36] INFO     Saving cached data to                                                   ]8;id=64420;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=210417;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#250\250]8;;\
#                              C:\Users\raphael.eugenio\soccerdata\data\Understat
# Provides pd.DataFrames from data at https://understat.com.
#
# Data will be downloaded as necessary and cached locally in
# ``~/soccerdata/data/Understat``.
#
# Parameters
# ----------
# proxy : 'tor' or or dict or list(dict) or callable, optional
#     Use a proxy to hide your IP address. Valid options are:
#         - "tor": Uses the Tor network. Tor should be running in
#           the background on port 9050.
#         - str: The address of the proxy server to use.
# ...

# %% [markdown]
# *Ligas*

# %%
leagues = understat.read_leagues()
leagues.head()
# Out:
#                league_id                                      url
# league
# GER-Bundesliga         3  https://understat.com/league/Bundesliga

# %% [markdown]
# *Temporadas*

# %%
seasons = understat.read_seasons()
seasons.head()
# Out:
#                       league_id  season_id  \
# league         season
# GER-Bundesliga 2425           3       2024
#
#                                                                 url
# league         season
# GER-Bundesliga 2425    https://understat.com/league/Bundesliga/2024

# %% [markdown]
# *Cronograma*

# %%
schedule = understat.read_schedule()
schedule.head()
# Out:
#                                                                        league_id  \
# league         season game
# GER-Bundesliga 2425   2024-08-23 Borussia M.Gladbach-Bayer Leverkusen          3
#                       2024-08-24 Augsburg-Werder Bremen                        3
#                       2024-08-24 Borussia Dortmund-Eintracht Frankfurt         3
#                       2024-08-24 Freiburg-VfB Stuttgart                        3
#                       2024-08-24 Hoffenheim-Holstein Kiel                      3
#
#                                                                         season_id  \
# league         season game
# GER-Bundesliga 2425   2024-08-23 Borussia M.Gladbach-Bayer Leverkusen        2024
#                       2024-08-24 Augsburg-Werder Bremen                      2024
#                       2024-08-24 Borussia Dortmund-Eintracht Frankfurt       2024
#                       2024-08-24 Freiburg-VfB Stuttgart                      2024
# ...

# %% [markdown]
# *Estatisticas da partidas por equipes*

# %%
team_match_stats = understat.read_team_match_stats()
team_match_stats.head()
# Out:
#                                                                        league_id  \
# league         season game
# GER-Bundesliga 2425   2024-08-23 Borussia M.Gladbach-Bayer Leverkusen          3
#                       2024-08-24 Augsburg-Werder Bremen                        3
#                       2024-08-24 Borussia Dortmund-Eintracht Frankfurt         3
#                       2024-08-24 Freiburg-VfB Stuttgart                        3
#                       2024-08-24 Hoffenheim-Holstein Kiel                      3
#
#                                                                         season_id  \
# league         season game
# GER-Bundesliga 2425   2024-08-23 Borussia M.Gladbach-Bayer Leverkusen        2024
#                       2024-08-24 Augsburg-Werder Bremen                      2024
#                       2024-08-24 Borussia Dortmund-Eintracht Frankfurt       2024
#                       2024-08-24 Freiburg-VfB Stuttgart                      2024
# ...

# %% [markdown]
# # QuemScoreou

# %%
ws = sd.WhoScored(leagues = "ITA-Serie A", seasons = 2021)
print(ws.__doc__)
# Out:
# [05/29/26 18:00:40] INFO     Saving cached data to                                                   ]8;id=469382;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=440865;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#250\250]8;;\
#                              C:\Users\raphael.eugenio\soccerdata\data\WhoScored
# [05/29/26 18:00:44] WARNING  c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\L ]8;id=50497;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\_py_warnings.py\_py_warnings.py]8;;\:]8;id=319957;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\_py_warnings.py#230\230]8;;\
#                              ib\site-packages\soccerdata\_common.py:144: UserWarning: Season id
#                              "2021" is ambiguous: interpreting as "20-21"
# ...

# %%
epl_schedule = ws.read_matches()
epl_schedule.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 epl_schedule = ws.read_matches()
#       2 epl_schedule.head()
#
# AttributeError: 'WhoScored' object has no attribute 'read_matches'
