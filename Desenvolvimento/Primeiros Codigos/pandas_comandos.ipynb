# %% [markdown]
# # Pandas primeiros comandos

# %%
pip install pandas # Instalação, apenas a primeira vez

# %%
# Importando o pacote
import pandas as pd

# %% [markdown]
# *Representação da tabela de dados dos Pandas*

# %%
# Criando Data Frame Simples
df = pd.DataFrame(
    {
        "Name":[
            "Lionel Messi",
            "Neymar Jr",
            "Cristiano Ronaldo",
        ],
        "Age" : [38, 34, 41],
        "Sex" : ["Male", "Male", "Male"],
    }
)
df
# Out:
#                 Name  Age   Sex
# 0       Lionel Messi   38  Male
# 1          Neymar Jr   34  Male
# 2  Cristiano Ronaldo   41  Male

# %% [markdown]
# *Só estou interessado em trabalhar com os dados da coluna: Age*

# %%
df["Age"]
# Out:
# 0    38
# 1    34
# 2    41
# Name: Age, dtype: int64

# %%
# Um pandas não tem rótulos de coluna, pois é apenas uma única coluna de um . A Série tem rótulos de linha.SeriesDataFrame
ages = pd.Series([38,34,41], name = "Age")
ages
# Out:
# 0    38
# 1    34
# 2    41
# Name: Age, dtype: int64

# %%
df["Age"].max() # vendo o valor maximo
df["Age"].min() # Vendo o valor minimo
# Out:
# np.int64(34)

# %%
# Usando a variavel
ages.max()
ages.min()
# Out:
# np.int64(34)

# %%
df.describe() # Estatisticas Basicas do DataFrame
# Out:
#              Age
# count   3.000000
# mean   37.666667
# std     3.511885
# min    34.000000
# 25%    36.000000
# 50%    38.000000
# 75%    39.500000
# max    41.000000

# %% [markdown]
# # Como eu leio e escrevo dados tabulares?

# %%
import csv

titanic = pd.read_csv(
    "C:/Users/raphael.eugenio/Desktop/Raphael/Outros/titanic.csv",
    encoding="utf-8-sig",
    quoting=csv.QUOTE_NONE,
    escapechar='\\'
)

# %%
titanic
# Out:
#       PassengerId  Survived       Pclass  \
# "1              0         3     ""Braund
# "2              1         1    ""Cumings
# "3              1         3  ""Heikkinen
# "4              1         1   ""Futrelle
# "5              0         3      ""Allen
# ...           ...       ...          ...
# "887            0         2   ""Montvila
# "888            1         1     ""Graham
# "889            0         3   ""Johnston
# "890            1         1       ""Behr
# "891            0         3     ""Dooley
#
#                                                Name     Sex   Age  SibSp  \
# "1                                Mr. Owen Harris""    male  22.0      1
# "2     Mrs. John Bradley (Florence Briggs Thayer)""  female  38.0      1
# "3                                     Miss Laina""  female  26.0      0
# "4             Mrs. Jacques Heath (Lily May Peel)""  female  35.0      1
# "5                              Mr. William Henry""    male  35.0      0
# ...

# %%
titanic.head(8) # Ve as Primeiras 8 linhas do df
# Out:
#     PassengerId  Survived       Pclass  \
# "1            0         3     ""Braund
# "2            1         1    ""Cumings
# "3            1         3  ""Heikkinen
# "4            1         1   ""Futrelle
# "5            0         3      ""Allen
# "6            0         3      ""Moran
# "7            0         1   ""McCarthy
# "8            0         3    ""Palsson
#
#                                              Name     Sex   Age  SibSp  Parch  \
# "1                              Mr. Owen Harris""    male  22.0      1      0
# "2   Mrs. John Bradley (Florence Briggs Thayer)""  female  38.0      1      0
# "3                                   Miss Laina""  female  26.0      0      0
# "4           Mrs. Jacques Heath (Lily May Peel)""  female  35.0      1      0
# "5                            Mr. William Henry""    male  35.0      0      0
# "6                                    Mr. James""    male   NaN      0      0
# ...

# %%
titanic.tail(8) # Print the last 8 lines of the df
# Out:
#       PassengerId  Survived      Pclass  \
# "884            0         2  ""Banfield
# "885            0         3  ""Sutehall
# "886            0         3      ""Rice
# "887            0         2  ""Montvila
# "888            1         1    ""Graham
# "889            0         3  ""Johnston
# "890            1         1      ""Behr
# "891            0         3    ""Dooley
#
#                                         Name     Sex   Age  SibSp  Parch  \
# "884                   Mr. Frederick James""    male  28.0      0      0
# "885                          Mr. Henry Jr""    male  25.0      0      0
# "886        Mrs. William (Margaret Norton)""  female  39.0      0      5
# "887                           Rev. Juozas""    male  27.0      0      0
# "888                   Miss Margaret Edith""  female  19.0      0      0
# "889   Miss Catherine Helen """"Carrie""""""  female   NaN      1      2
# "890                       Mr. Karl Howell""    male  26.0      0      0
# ...

# %%
titanic.dtypes # Verifica o tipo da variável
# Out:
# PassengerId      int64
# Survived         int64
# Pclass             str
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
# Enviando para arquivo .xlsx
titanic.to_excel("titanic.xlsx", sheet_name = "passengers", index = False)

# %%
# Trazendo arquivo em .xlsx
titanic = pd.read_excel("titanic.xlsx", sheet_name= "passengers")

# %%
# Resumo Tecnico de um DataFrame
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    str
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     891 non-null    str
# dtypes: float64(2), int64(4), str(6)
# memory usage: 83.7 KB

# %% [markdown]
# # Como faço para selecionar um subconjunto de um DataFrame

# %%
# Quero a idade dos passageiros do titanic
ages = titanic["Age"]

ages.head(7)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# Name: Age, dtype: float64

# %%
type(titanic["Age"])
# Out:
# pandas.Series

# %%
titanic[["Age","Sex"]].shape
# Out:
# (891, 2)

# %%
# Selecionando 2 ou mais colunas
age_sex = titanic[["Age", "Sex"]]
age_sex.head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
# Filtrando passageiros acima de 35 anos
above_35 = titanic[titanic["Age"] > 35]
above_35
# Out:
#      PassengerId  Survived             Pclass  \
# 1              1         1          ""Cumings
# 6              0         1         ""McCarthy
# 11             1         1          ""Bonnell
# 13             0         3        ""Andersson
# 15             1         2          ""Hewlett
# ..           ...       ...                ...
# 865            1         2          ""Bystrom
# 871            1         1         ""Beckwith
# 873            0         3  ""Vander Cruyssen
# 879            1         1           ""Potter
# 885            0         3             ""Rice
#
#                                               Name     Sex   Age  SibSp  \
# 1     Mrs. John Bradley (Florence Briggs Thayer)""  female  38.0      1
# 6                                  Mr. Timothy J""    male  54.0      0
# 11                                Miss Elizabeth""  female  58.0      0
# 13                              Mr. Anders Johan""    male  39.0      1
# ...

# %%
titanic["Age"] > 35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
# Tamanho do df criado
above_35.shape
# Out:
# (217, 12)

# %%
class_23 = titanic[titanic["Survived"].isin([2, 3])]
class_23
# Out:
#      PassengerId  Survived       Pclass  \
# 0              0         3     ""Braund
# 2              1         3  ""Heikkinen
# 4              0         3      ""Allen
# 5              0         3      ""Moran
# 7              0         3    ""Palsson
# ..           ...       ...          ...
# 884            0         3   ""Sutehall
# 885            0         3       ""Rice
# 886            0         2   ""Montvila
# 888            0         3   ""Johnston
# 890            0         3     ""Dooley
#
#                                        Name     Sex   Age  SibSp  Parch  \
# 0                         Mr. Owen Harris""    male  22.0      1      0
# 2                              Miss Laina""  female  26.0      0      0
# 4                       Mr. William Henry""    male  35.0      0      0
# 5                               Mr. James""    male   NaN      0      0
# 7                    Master Gosta Leonard""    male   2.0      3      1
# ...

# %%
age_no_na = titanic[titanic["Age"].notna()]
age_no_na.head()
# Out:
#    PassengerId  Survived       Pclass  \
# 0            0         3     ""Braund
# 1            1         1    ""Cumings
# 2            1         3  ""Heikkinen
# 3            1         1   ""Futrelle
# 4            0         3      ""Allen
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris""    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)""  female  38.0      1      0
# 2                                   Miss Laina""  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)""  female  35.0      1      0
# 4                            Mr. William Henry""    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN       S"
# 1          PC 17599  71.2833   C85       C"
# 2  STON/O2. 3101282   7.9250   NaN       S"
# 3            113803  53.1000  C123       S"
# 4            373450   8.0500   NaN       S"
