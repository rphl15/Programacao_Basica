# %% [markdown]
# *Importando o Pandas*

# %%
import pandas as pd

#definindo quantidade de linhas e colunas visiveis
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# *Importação de arquivos EXCEL*

# %%
hospital = 'SANTA_ISABEL'
mes = 'ABR'
caminho = ('G:/Drives compartilhados/Qualidade/ACURÁCIA/CATE 3136/2026/04 - ABR/')
df = pd.read_excel(caminho + 'CATE3136_' + hospital + '_' + mes + '26.xlsx')
df_bck = df.copy()

# %%
df['Cor'] = ''

# %%
df['Setor/Sala'].value_counts()
df['Setor/Sala'].str.contains('Hemodinâmica|Centro Obstétrico|CO', case=False, na=False)

# %%
verde = df['Setor/Sala'].str.contains('Hemodinâmica|Centro Obstétrico|CO', case=False, na=False)
df.loc[verde, 'Cor'] = 'Verde'

print(df[df['Setor/Sala'].str.contains('Hemodinâmica|Centro Obstétrico', case=False, na=False)])

# %% [markdown]
# *Obtendo nomes das colunas*

# %%
df.columns

# %% [markdown]
# *Remover linhas que não contem resposta*

# %%
condicao = (
    df['Setor/Sala'].isnull() &
    df['Tipo Anestesia'].str.contains(
        'Local|Local Assistida|Sem Analgesia',
        case=False,
        na=False
    )
)
df.loc[condicao, 'Cor'] = 'Amarelo'
print(df.loc[condicao, 'Cor'])

# %% [markdown]
# *Filtrando os dados*

# %%
palavras = (
    'Postectomia',
    'Vasectomia',
    'Retirada de Cateter',
    'Retirada de duplo j',
    'Entensos Ferimentos',
    'Endoscopia',
    'Colonoscopia',
    'Infiltração',
    'Denervação',
    'Bloqueio',
    'Túnel',
    'Exérese',
    'Aspiração Manual'    
)

padrao = '|'.join(palavras)

vazios = (
    df['Tipo Anestesia'].isnull() &
    df['Ds procedimento'].str.contains(padrao, case=False, na=False) &
    df['Proced adicional'].isnull()
)
df.loc[vazios, 'Tipo Anestesia'] = 'Sedação'

# %%
# Adicionando "Anestesia" em campos vazios
df.loc[
    df['Tipo Anestesia'].isnull() |
    (df['Tipo Anestesia'].str.strip() == ''),
    'Tipo Anestesia'
] = 'Anestesia'

# %% [markdown]
# *Removendo caracteres indesejados*

# %%
len(df)

# %%
display(df_bck.loc[26:26])

display(df.loc[26:26])

# %%
len(df)

# %%
caminho_export = ("G:/Drives compartilhados/Qualidade/ACURÁCIA/INDICADORES CC/2026/ABR/")
df.to_excel(caminho_export + 'CC_' + hospital + '_' + mes + '2026.xlsx')
