# %%
import soccerdata as sd
# Out:
# [05/29/26 14:31:51] INFO     No custom team name replacements found. You can configure these in       ]8;id=313989;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=342356;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_config.py#92\92]8;;\
#                              C:\Users\raphael.eugenio\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=775599;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=678079;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_config.py#190\190]8;;\
#                              C:\Users\raphael.eugenio\soccerdata\config\league_dict.json.

# %% [markdown]
# # Extração de Dados

# %%
# Criar instância da classe scraper
fbref = sd.FBref()
# Out:
# [05/29/26 14:32:42] INFO     Saving cached data to C:\Users\raphael.eugenio\soccerdata\data\FBref    ]8;id=751598;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=295361;file://c:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\soccerdata\_common.py#250\250]8;;\
# *** chromedriver to download = 148.0.7778.178 (Previous Version)
#
# ...
# https://storage.googleapis.com/chrome-for-testing-public/148.0.7778.178/win64/chromedriver-win64.zip ...
# Download Complete!
#
# Extracting ['chromedriver.exe'] from chromedriver-win64.zip ...
# Unzip Complete!
#
# The file [chromedriver.exe] was saved to:
# C:\Users\raphael.eugenio\AppData\Local\Programs\Python\Python314\Lib\site-packages\seleniumbase\drivers\
# chromedriver.exe
#
# Making [chromedriver.exe 148.0.7778.178] executable ...
# [chromedriver.exe 148.0.7778.178] is now ready for use!
# ...
